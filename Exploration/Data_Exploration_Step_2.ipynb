# %%
from __future__ import absolute_import, division, print_function


import numpy
import os
import pandas
from pandas import DataFrame, Series
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams

wd = os.getcwd()
os.chdir('/Users/travisgreenwald/downloads/')
dfArrests = pandas.read_csv('JSS_RawArrests.csv')
dfArrests = DataFrame(dfArrests)
dfArrests.head()
# Out:
# /Users/travisgreenwald/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID\t \tAB_RT\t  \tAB_RIN\t \tARREST_TYPE\t  \tArrest_RIN\t  \
# 0     1        AB      342729              DS          342729
# 1     2        AB      342729              DS          342729
# 2     3        AB      342729              DS          342729
# 3     4        AB      342739              DS          342739
# 4     5        AB      252007              DS          252007
#
#   \tArrestPrimaryKey\t \tARREST_OFFICER1\t \tORGANIZATION\t  \
# 0            201439059              P13102               D6
# 1            201439059              P13102               D6
# 2            201439059              P13102               D6
# 3            201439064              P79020              JUV
# ...

# %% [markdown]
# ## Top 10 days by number of arrests

# %%
dateSlice = dfArrests['\tARREST_DATE\t']
dateSlice = pandas.to_datetime(dateSlice)
grpDate = dfArrests.groupby('\tARREST_DATE\t')
dailyCount = grpDate['ID\t'].count()
dailyCount = dailyCount.sort_values(ascending=False)
dailyCount = DataFrame(dailyCount)
dailyCount[:10]
# Out:
#                  ID\t
# \tARREST_DATE\t
# 8/8/15 0:00       426
# 1/27/16 0:00      344
# 3/3/16 0:00       344
# 4/19/15 0:00      339
# 5/16/15 0:00      320
# 9/24/15 0:00      320
# 7/15/15 0:00      320
# 5/3/15 0:00       317
# 2/3/16 0:00       317
# 2/5/16 0:00       316

# %% [markdown]
# ## Line plot for dates vs number of arrests

# %%
dailyCount = grpDate['ID\t'].count()
dailyCount = dailyCount['2015-1-1':]
dailyCount.plot(figsize = (20,6))
plt.xlabel('Date')
plt.ylabel('Number of arrests')
plt.title('Arrests by date')
